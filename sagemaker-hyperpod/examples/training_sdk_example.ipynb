# %% [markdown]
# ## HyperPod Training SDK Experience

# %%
import sys
import warnings

warnings.filterwarnings("ignore")
sys.path.insert(0, '/Users/pintaoz/workspace/private-sagemaker-hyperpod-cli-staging/sagemaker-hyperpod/src/sagemaker')
sys.path
# Out:
# ['/Users/pintaoz/workspace/private-sagemaker-hyperpod-cli-staging/sagemaker-hyperpod/src/sagemaker',
#  '/Users/pintaoz/.pyenv/versions/3.10.14/lib/python310.zip',
#  '/Users/pintaoz/.pyenv/versions/3.10.14/lib/python3.10',
#  '/Users/pintaoz/.pyenv/versions/3.10.14/lib/python3.10/lib-dynload',
#  '',
#  '/Users/pintaoz/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages']

# %% [markdown]
# ### Create a HyperPodTrainingJob with a full spec

# %%
from sagemaker.hyperpod.training.hyperpod_pytorch_job import HyperPodPytorchJob
from sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config import (
    _HyperPodPytorchJob,
    Container,
    ReplicaSpec,
    Resources,
    RunPolicy,
    Spec,
    Template,
)
from sagemaker.hyperpod.inference.config.common import Metadata

spec = _HyperPodPytorchJob(
    nproc_per_node="1",
    replica_specs=[
        ReplicaSpec(
            name="pod",
            template=Template(
                spec=Spec(
                    containers=[
                        Container(
                            name="container-name",
                            image="448049793756.dkr.ecr.us-west-2.amazonaws.com/ptjob:mnist",
                            image_pull_policy="Always",
                            resources=Resources(
                                requests={"nvidia.com/gpu": "0"},
                                limits={"nvidia.com/gpu": "0"},
                            ),
                            # command=[]
                        )
                    ]
                )
            ),
        )
    ],
    run_policy=RunPolicy(clean_pod_policy="None"),
)

pytorch_job = HyperPodPytorchJob(metadata=Metadata(name="demo"), spec=spec)
pytorch_job.create()
# Out:
# Deploying HyperPodPytorchJob with config:
# apiVersion: sagemaker.amazonaws.com/v1
# kind: HyperPodPyTorchJob
# metadata:
#   labels: null
#   name: demo
#   namespace: default
# spec:
#   nprocPerNode: '1'
#   replicaSpecs:
#   - name: pod
#     replicas: 1
#     spares: 0
#     template:
#       metadata: null
#       spec:
#         activeDeadlineSeconds: null
#         affinity: null
#         automountServiceAccountToken: null
#         containers:
#         - args: null
#           command: null
#           env: null
#           envFrom: null
#           image: 448049793756.dkr.ecr.us-west-2.amazonaws.com/ptjob:mnist
#           imagePullPolicy: Always
#           lifecycle: null
#           livenessProbe: null
#           name: container-name
#           ports: null
#           readinessProbe: null
#           resizePolicy: null
#           resources:
#             claims: null
#             limits:
#               nvidia.com/gpu: '0'
#             requests:
#               nvidia.com/gpu: '0'
#           restartPolicy: null
#           securityContext: null
#           startupProbe: null
#           stdin: null
#           stdinOnce: null
#           terminationMessagePath: null
#           terminationMessagePolicy: null
#           tty: null
#           volumeDevices: null
#           volumeMounts: null
#           workingDir: null
#         dnsConfig: null
#         dnsPolicy: null
#         enableServiceLinks: null
#         ephemeralContainers: null
#         hostAliases: null
#         hostIPC: null
#         hostNetwork: null
#         hostPID: null
#         hostUsers: null
#         hostname: null
#         imagePullSecrets: null
#         initContainers: null
#         nodeName: null
#         nodeSelector: null
#         os: null
#         overhead: null
#         preemptionPolicy: null
#         priority: null
#         priorityClassName: null
#         readinessGates: null
#         resourceClaims: null
#         restartPolicy: null
#         runtimeClassName: null
#         schedulerName: null
#         schedulingGates: null
#         securityContext: null
#         serviceAccount: null
#         serviceAccountName: null
#         setHostnameAsFQDN: null
#         shareProcessNamespace: null
#         subdomain: null
#         terminationGracePeriodSeconds: null
#         tolerations: null
#         topologySpreadConstraints: null
#         volumes: null
#   runPolicy:
#     activeDeadlineSeconds: null
#     cleanPodPolicy: None
#     faultDeadlineSeconds: null
#     jobMaxRetryCount: null
#     logMonitoringConfiguration: null
#     restartPolicy: null
#     startupDeadlineSeconds: null
#     suspend: null
#     ttlSecondsAfterFinished: 0
#
# Failed to create HyperPodPytorchJob demo!
# exception type <class 'kubernetes.client.exceptions.ApiException'>
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/sagemaker/hyperpod/training/hyperpod_pytorch_job.py:75, in HyperPodPytorchJob.create(self)
#      74 try:
# ---> 75     custom_api.create_namespaced_custom_object(
#      76         group=TRAINING_GROUP,
#      77         version=API_VERSION,
#      78         namespace=self.metadata.namespace,
#      79         plural=PLURAL,
#      80         body=self.config(),
#      81     )
#      82     print("Successful submitted HyperPodPytorchJob!")
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/kubernetes/client/api/custom_objects_api.py:231, in CustomObjectsApi.create_namespaced_custom_object(self, group, version, namespace, plural, body, **kwargs)
#     230 kwargs['_return_http_data_only'] = True
# --> 231 return self.create_namespaced_custom_object_with_http_info(group, version, namespace, plural, body, **kwargs)
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/kubernetes/client/api/custom_objects_api.py:354, in CustomObjectsApi.create_namespaced_custom_object_with_http_info(self, group, version, namespace, plural, body, **kwargs)
#     352 auth_settings = ['BearerToken']  # noqa: E501
# --> 354 return self.api_client.call_api(
#     355     '/apis/{group}/{version}/namespaces/{namespace}/{plural}', 'POST',
#     356     path_params,
#     357     query_params,
#     358     header_params,
#     359     body=body_params,
#     360     post_params=form_params,
#     361     files=local_var_files,
#     362     response_type='object',  # noqa: E501
#     363     auth_settings=auth_settings,
#     364     async_req=local_var_params.get('async_req'),
#     365     _return_http_data_only=local_var_params.get('_return_http_data_only'),  # noqa: E501
#     366     _preload_content=local_var_params.get('_preload_content', True),
#     367     _request_timeout=local_var_params.get('_request_timeout'),
#     368     collection_formats=collection_formats)
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/kubernetes/client/api_client.py:348, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     347 if not async_req:
# --> 348     return self.__call_api(resource_path, method,
#     349                            path_params, query_params, header_params,
#     350                            body, post_params, files,
#     351                            response_type, auth_settings,
#     352                            _return_http_data_only, collection_formats,
#     353                            _preload_content, _request_timeout, _host)
#     355 return self.pool.apply_async(self.__call_api, (resource_path,
#     356                                                method, path_params,
#     357                                                query_params,
#    (...)
#     365                                                _request_timeout,
#     366                                                _host))
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/kubernetes/client/api_client.py:180, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     179 # perform request and return response
# --> 180 response_data = self.request(
#     181     method, url, query_params=query_params, headers=header_params,
#     182     post_params=post_params, body=body,
#     183     _preload_content=_preload_content,
#     184     _request_timeout=_request_timeout)
#     186 self.last_response = response_data
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/kubernetes/client/api_client.py:391, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     390 elif method == "POST":
# --> 391     return self.rest_client.POST(url,
#     392                                  query_params=query_params,
#     393                                  headers=headers,
#     394                                  post_params=post_params,
#     395                                  _preload_content=_preload_content,
#     396                                  _request_timeout=_request_timeout,
#     397                                  body=body)
#     398 elif method == "PUT":
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/kubernetes/client/rest.py:279, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     277 def POST(self, url, headers=None, query_params=None, post_params=None,
#     278          body=None, _preload_content=True, _request_timeout=None):
# --> 279     return self.request("POST", url,
#     280                         headers=headers,
#     281                         query_params=query_params,
#     282                         post_params=post_params,
#     283                         _preload_content=_preload_content,
#     284                         _request_timeout=_request_timeout,
#     285                         body=body)
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/kubernetes/client/rest.py:238, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     237 if not 200 <= r.status <= 299:
# --> 238     raise ApiException(http_resp=r)
#     240 return r
#
# ApiException: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Audit-Id': '78880467-2cbe-4182-af34-b449b2c7ac49', 'Cache-Control': 'no-cache, private', 'Content-Type': 'application/json', 'Warning': '299 - "CleanPod Policy is \'None\'. This means that not all pods will be cleaned up when job is finished."', 'X-Kubernetes-Pf-Flowschema-Uid': '248becfd-4f98-4de5-b377-064f332d2bb6', 'X-Kubernetes-Pf-Prioritylevel-Uid': '6ad262e2-7c1d-46b0-bb7e-ab95e8d080b0', 'Date': 'Sun, 29 Jun 2025 21:48:36 GMT', 'Content-Length': '274'})
# HTTP response body: {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"hyperpodpytorchjobs.sagemaker.amazonaws.com \"demo\" already exists","reason":"AlreadyExists","details":{"name":"demo","group":"sagemaker.amazonaws.com","kind":"hyperpodpytorchjobs"},"code":409}
#
#
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 40
#      13 spec = _HyperPodPytorchJob(
#      14     nproc_per_node="1",
#      15     replica_specs=[
#    (...)
#      36     run_policy=RunPolicy(clean_pod_policy="None"),
#      37 )
#      39 pytorch_job = HyperPodPytorchJob(metadata=Metadata(name="demo"), spec=spec)
# ---> 40 pytorch_job.create()
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/sagemaker/hyperpod/training/hyperpod_pytorch_job.py:85, in HyperPodPytorchJob.create(self)
#      83 except Exception as e:
#      84     print(f"Failed to create HyperPodPytorchJob {self.metadata.name}!")
# ---> 85     _handel_exception(e, self.metadata.name, self.metadata.namespace)
#
# File ~/.pyenv/versions/3.10.14/envs/py3.10/lib/python3.10/site-packages/sagemaker/hyperpod/training/hyperpod_pytorch_job.py:222, in _handel_exception(e, name, namespace)
#     220     raise Exception(f"Access denied to resource '{name}' in '{namespace}'.") from e
#     221 elif e.status == 409:
# --> 222     raise Exception(f"Resource '{name}' already exists in '{namespace}'.") from e
#     223 elif 500 <= e.status < 600:
#     224     raise Exception("Kubernetes API internal server error.") from e
#
# Exception: Resource 'demo' already exists in 'default'.

# %% [markdown]
# ### Get the status of created jobs

# %%
import yaml
print("List all jobs:")
print(yaml.dump(HyperPodPytorchJob.list()))

print("Refresh job demo and check the status:")
pytorch_job.refresh()
print(yaml.dump(pytorch_job.status))
# Out:
# List all jobs:
# - !!python/object:sagemaker.hyperpod.training.hyperpod_pytorch_job.HyperPodPytorchJob
#   __dict__:
#     apiVersion: sagemaker.amazonaws.com/v1
#     kind: HyperPodPyTorchJob
#     metadata: !!python/object:sagemaker.hyperpod.inference.config.common.Metadata
#       __dict__:
#         labels: null
#         name: create-from-spec-demo-5
#         namespace: default
#       __pydantic_extra__: null
#       __pydantic_fields_set__: !!set
#         name: null
#         namespace: null
#       __pydantic_private__: null
#     spec: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config._HyperPodPytorchJob
#       __dict__:
#         nprocPerNode: '1'
#         replicaSpecs:
#         - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.ReplicaSpec
#           __dict__:
#             name: pod
#             replicas: 1
#             spares: 0
#             template: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Template
#               __dict__:
#                 metadata: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Metadata
#                   __dict__:
#                     annotations: null
#                     finalizers: null
#                     labels: null
#                     name: null
#                     namespace: null
#                   __pydantic_extra__: null
#                   __pydantic_fields_set__: !!set {}
#                   __pydantic_private__: null
#                 spec: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Spec
#                   __dict__:
#                     activeDeadlineSeconds: null
#                     affinity: null
#                     automountServiceAccountToken: null
#                     containers:
#                     - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Container
#                       __dict__:
#                         args: null
#                         command: null
#                         env: null
#                         envFrom: null
#                         image: 448049793756.dkr.ecr.us-west-2.amazonaws.com/ptjob:mnist
#                         imagePullPolicy: Always
#                         lifecycle: null
#                         livenessProbe: null
#                         name: container-name
#                         ports: null
#                         readinessProbe: null
#                         resizePolicy: null
#                         resources: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Resources
#                           __dict__:
#                             claims: null
#                             limits:
#                               nvidia.com/gpu: '0'
#                             requests:
#                               nvidia.com/gpu: '0'
#                           __pydantic_extra__: null
#                           __pydantic_fields_set__: !!set
#                             limits: null
#                             requests: null
#                           __pydantic_private__: null
#                         restartPolicy: null
#                         securityContext: null
#                         startupProbe: null
#                         stdin: null
#                         stdinOnce: null
#                         terminationMessagePath: null
#                         terminationMessagePolicy: null
#                         tty: null
#                         volumeDevices: null
#                         volumeMounts: null
#                         workingDir: null
#                       __pydantic_extra__: null
#                       __pydantic_fields_set__: !!set
#                         image: null
#                         imagePullPolicy: null
#                         name: null
#                         resources: null
#                       __pydantic_private__: null
#                     dnsConfig: null
#                     dnsPolicy: null
#                     enableServiceLinks: null
#                     ephemeralContainers: null
#                     hostAliases: null
#                     hostIPC: null
#                     hostNetwork: null
#                     hostPID: null
#                     hostUsers: null
#                     hostname: null
#                     imagePullSecrets: null
#                     initContainers: null
#                     nodeName: null
#                     nodeSelector: null
#                     os: null
#                     overhead: null
#                     preemptionPolicy: null
#                     priority: null
#                     priorityClassName: null
#                     readinessGates: null
#                     resourceClaims: null
#                     restartPolicy: null
#                     runtimeClassName: null
#                     schedulerName: null
#                     schedulingGates: null
#                     securityContext: null
#                     serviceAccount: null
#                     serviceAccountName: null
#                     setHostnameAsFQDN: null
#                     shareProcessNamespace: null
#                     subdomain: null
#                     terminationGracePeriodSeconds: null
#                     tolerations: null
#                     topologySpreadConstraints: null
#                     volumes: null
#                   __pydantic_extra__: null
#                   __pydantic_fields_set__: !!set
#                     containers: null
#                   __pydantic_private__: null
#               __pydantic_extra__: null
#               __pydantic_fields_set__: !!set
#                 metadata: null
#                 spec: null
#               __pydantic_private__: null
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             name: null
#             replicas: null
#             spares: null
#             template: null
#           __pydantic_private__: null
#         runPolicy: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.RunPolicy
#           __dict__:
#             activeDeadlineSeconds: null
#             cleanPodPolicy: None
#             faultDeadlineSeconds: null
#             jobMaxRetryCount: null
#             logMonitoringConfiguration: null
#             restartPolicy: null
#             startupDeadlineSeconds: null
#             suspend: null
#             ttlSecondsAfterFinished: 0
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             cleanPodPolicy: null
#             ttlSecondsAfterFinished: null
#           __pydantic_private__: null
#       __pydantic_extra__: null
#       __pydantic_fields_set__: !!set
#         nprocPerNode: null
#         replicaSpecs: null
#         runPolicy: null
#       __pydantic_private__: null
#     status: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.HyperPodPytorchJobStatus
#       __dict__:
#         completionTime: null
#         conditions:
#         - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.Conditions
#           __dict__:
#             lastProbeTime: null
#             lastTransitionTime: '2025-06-24T19:20:58Z'
#             message: null
#             reason: null
#             status: 'True'
#             type: Created
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             lastTransitionTime: null
#             status: null
#             type: null
#           __pydantic_private__: null
#         - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.Conditions
#           __dict__:
#             lastProbeTime: null
#             lastTransitionTime: '2025-06-24T19:32:00Z'
#             message: null
#             reason: null
#             status: 'True'
#             type: Completed
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             lastTransitionTime: null
#             status: null
#             type: null
#           __pydantic_private__: null
#         jobPods: null
#         managerPods: null
#         masterAddr: 10.1.164.190
#         masterPort: '1234'
#         podManagerStatuses: null
#         podSetInfos: null
#         podSets: null
#         restartCount: 0
#         restartStatus: null
#         startTime: null
#       __pydantic_extra__: null
#       __pydantic_fields_set__: !!set
#         conditions: null
#         masterAddr: null
#         masterPort: null
#         restartCount: null
#       __pydantic_private__: null
#   __pydantic_extra__: null
#   __pydantic_fields_set__: !!set
#     metadata: null
#     spec: null
#     status: null
#   __pydantic_private__: null
# - !!python/object:sagemaker.hyperpod.training.hyperpod_pytorch_job.HyperPodPytorchJob
#   __dict__:
#     apiVersion: sagemaker.amazonaws.com/v1
#     kind: HyperPodPyTorchJob
#     metadata: !!python/object:sagemaker.hyperpod.inference.config.common.Metadata
#       __dict__:
#         labels: null
#         name: demo
#         namespace: default
#       __pydantic_extra__: null
#       __pydantic_fields_set__: !!set
#         name: null
#         namespace: null
#       __pydantic_private__: null
#     spec: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config._HyperPodPytorchJob
#       __dict__:
#         nprocPerNode: '1'
#         replicaSpecs:
#         - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.ReplicaSpec
#           __dict__:
#             name: pod
#             replicas: 1
#             spares: 0
#             template: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Template
#               __dict__:
#                 metadata: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Metadata
#                   __dict__:
#                     annotations: null
#                     finalizers: null
#                     labels: null
#                     name: null
#                     namespace: null
#                   __pydantic_extra__: null
#                   __pydantic_fields_set__: !!set {}
#                   __pydantic_private__: null
#                 spec: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Spec
#                   __dict__:
#                     activeDeadlineSeconds: null
#                     affinity: null
#                     automountServiceAccountToken: null
#                     containers:
#                     - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Container
#                       __dict__:
#                         args: null
#                         command: null
#                         env: null
#                         envFrom: null
#                         image: 448049793756.dkr.ecr.us-west-2.amazonaws.com/ptjob:mnist
#                         imagePullPolicy: Always
#                         lifecycle: null
#                         livenessProbe: null
#                         name: container-name
#                         ports: null
#                         readinessProbe: null
#                         resizePolicy: null
#                         resources: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.Resources
#                           __dict__:
#                             claims: null
#                             limits:
#                               nvidia.com/gpu: '0'
#                             requests:
#                               nvidia.com/gpu: '0'
#                           __pydantic_extra__: null
#                           __pydantic_fields_set__: !!set
#                             limits: null
#                             requests: null
#                           __pydantic_private__: null
#                         restartPolicy: null
#                         securityContext: null
#                         startupProbe: null
#                         stdin: null
#                         stdinOnce: null
#                         terminationMessagePath: null
#                         terminationMessagePolicy: null
#                         tty: null
#                         volumeDevices: null
#                         volumeMounts: null
#                         workingDir: null
#                       __pydantic_extra__: null
#                       __pydantic_fields_set__: !!set
#                         image: null
#                         imagePullPolicy: null
#                         name: null
#                         resources: null
#                       __pydantic_private__: null
#                     dnsConfig: null
#                     dnsPolicy: null
#                     enableServiceLinks: null
#                     ephemeralContainers: null
#                     hostAliases: null
#                     hostIPC: null
#                     hostNetwork: null
#                     hostPID: null
#                     hostUsers: null
#                     hostname: null
#                     imagePullSecrets: null
#                     initContainers: null
#                     nodeName: null
#                     nodeSelector: null
#                     os: null
#                     overhead: null
#                     preemptionPolicy: null
#                     priority: null
#                     priorityClassName: null
#                     readinessGates: null
#                     resourceClaims: null
#                     restartPolicy: null
#                     runtimeClassName: null
#                     schedulerName: null
#                     schedulingGates: null
#                     securityContext: null
#                     serviceAccount: null
#                     serviceAccountName: null
#                     setHostnameAsFQDN: null
#                     shareProcessNamespace: null
#                     subdomain: null
#                     terminationGracePeriodSeconds: null
#                     tolerations: null
#                     topologySpreadConstraints: null
#                     volumes: null
#                   __pydantic_extra__: null
#                   __pydantic_fields_set__: !!set
#                     containers: null
#                   __pydantic_private__: null
#               __pydantic_extra__: null
#               __pydantic_fields_set__: !!set
#                 metadata: null
#                 spec: null
#               __pydantic_private__: null
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             name: null
#             replicas: null
#             spares: null
#             template: null
#           __pydantic_private__: null
#         runPolicy: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_config.RunPolicy
#           __dict__:
#             activeDeadlineSeconds: null
#             cleanPodPolicy: None
#             faultDeadlineSeconds: null
#             jobMaxRetryCount: null
#             logMonitoringConfiguration: null
#             restartPolicy: null
#             startupDeadlineSeconds: null
#             suspend: null
#             ttlSecondsAfterFinished: 0
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             cleanPodPolicy: null
#             ttlSecondsAfterFinished: null
#           __pydantic_private__: null
#       __pydantic_extra__: null
#       __pydantic_fields_set__: !!set
#         nprocPerNode: null
#         replicaSpecs: null
#         runPolicy: null
#       __pydantic_private__: null
#     status: !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.HyperPodPytorchJobStatus
#       __dict__:
#         completionTime: null
#         conditions:
#         - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.Conditions
#           __dict__:
#             lastProbeTime: null
#             lastTransitionTime: '2025-06-29T21:45:23Z'
#             message: null
#             reason: null
#             status: 'True'
#             type: Created
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             lastTransitionTime: null
#             status: null
#             type: null
#           __pydantic_private__: null
#         - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.Conditions
#           __dict__:
#             lastProbeTime: null
#             lastTransitionTime: '2025-06-29T21:46:10Z'
#             message: null
#             reason: null
#             status: 'True'
#             type: Completed
#           __pydantic_extra__: null
#           __pydantic_fields_set__: !!set
#             lastTransitionTime: null
#             status: null
#             type: null
#           __pydantic_private__: null
#         jobPods: null
#         managerPods: null
#         masterAddr: 10.1.176.117
#         masterPort: '1234'
#         podManagerStatuses: null
#         podSetInfos: null
#         podSets: null
#         restartCount: 0
#         restartStatus: null
#         startTime: null
#       __pydantic_extra__: null
#       __pydantic_fields_set__: !!set
#         conditions: null
#         masterAddr: null
#         masterPort: null
#         restartCount: null
#       __pydantic_private__: null
#   __pydantic_extra__: null
#   __pydantic_fields_set__: !!set
#     metadata: null
#     spec: null
#     status: null
#   __pydantic_private__: null
#
#
# Refresh job demo and check the status:
# !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.HyperPodPytorchJobStatus
# __dict__:
#   completionTime: null
#   conditions:
#   - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.Conditions
#     __dict__:
#       lastProbeTime: null
#       lastTransitionTime: '2025-06-29T21:45:23Z'
#       message: null
#       reason: null
#       status: 'True'
#       type: Created
#     __pydantic_extra__: null
#     __pydantic_fields_set__: !!set
#       lastTransitionTime: null
#       status: null
#       type: null
#     __pydantic_private__: null
#   - !!python/object:sagemaker.hyperpod.training.config.hyperpod_pytorch_job_status.Conditions
#     __dict__:
#       lastProbeTime: null
#       lastTransitionTime: '2025-06-29T21:46:10Z'
#       message: null
#       reason: null
#       status: 'True'
#       type: Completed
#     __pydantic_extra__: null
#     __pydantic_fields_set__: !!set
#       lastTransitionTime: null
#       status: null
#       type: null
#     __pydantic_private__: null
#   jobPods: null
#   managerPods: null
#   masterAddr: 10.1.176.117
#   masterPort: '1234'
#   podManagerStatuses: null
#   podSetInfos: null
#   podSets: null
#   restartCount: 0
#   restartStatus: null
#   startTime: null
# __pydantic_extra__: null
# __pydantic_fields_set__: !!set
#   conditions: null
#   masterAddr: null
#   masterPort: null
#   restartCount: null
# __pydantic_private__: null

# %% [markdown]
# ### Get model training logs from the pod

# %%
print("List all pods created for this job:")
print(pytorch_job.list_pods())

print("Check the logs from pod0:")
print(pytorch_job.get_logs_from_pod("demo-pod-0"))
# Out:
# List all pods created for this job:
# ['demo-pod-0', 'demo-podmanagers-0']
# Check the logs from pod0:
# 2025-06-29T21:45:26.710683365Z [HyperPodElasticAgent] 2025-06-29 21:45:26,710 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/run.py:68: Agent Version: 1.1.20250621203754
# 2025-06-29T21:45:26.710713625Z [HyperPodElasticAgent] 2025-06-29 21:45:26,710 [WARNING] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/run.py:72: Overriding `rdzv_backend='hyperpod'`
# 2025-06-29T21:45:26.711332626Z INFO:Log Agent:Log agent is ready, log agent logs will be saved to /tmp/log_agent_8g5qj5q8.log
# 2025-06-29T21:45:26.711777464Z [HyperPodElasticAgent] 2025-06-29 21:45:26,711 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/ipc/socket.py:161: Server started on /tmp/hyperpod_elastic_agent_1.sock
# 2025-06-29T21:45:26.711788125Z [HyperPodElasticAgent] 2025-06-29 21:45:26,711 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/ipc/server.py:66: Started CheckpointDiscoverySocketServer over /tmp/hyperpod_elastic_agent_1.sock
# 2025-06-29T21:45:26.711925367Z [HyperPodElasticAgent] 2025-06-29 21:45:26,711 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:344: Transitioned from AgentState.INIT to AgentState.READY
# 2025-06-29T21:45:26.711932777Z [HyperPodElasticAgent] 2025-06-29 21:45:26,711 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:346: The agent is ready to begin training, and is waiting for the rest of the training agents to be ready. It will begin running when it receives a start signal from the HyperPodTrainingOperator
# 2025-06-29T21:45:26.731159211Z INFO:     Started server process [1]
# 2025-06-29T21:45:26.731173281Z INFO:     Waiting for application startup.
# 2025-06-29T21:45:26.731312464Z INFO:     Application startup complete.
# 2025-06-29T21:45:26.732570316Z INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
# 2025-06-29T21:45:26.751487535Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:27.798031712Z [HyperPodElasticAgent] 2025-06-29 21:45:27,797 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:344: Transitioned from AgentState.READY to AgentState.RUNNING
# 2025-06-29T21:45:27.798051402Z [HyperPodElasticAgent] 2025-06-29 21:45:27,797 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:346: The agent is now running the training script
# 2025-06-29T21:45:27.798355528Z INFO:     10.1.230.236:41788 - "POST /start HTTP/1.1" 200 OK
# 2025-06-29T21:45:27.815871722Z [HyperPodElasticAgent] 2025-06-29 21:45:27,815 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/plr_hyperpod_elastic_agent.py:118: [default] Agent starting workers for entrypoint: python.
# 2025-06-29T21:45:27.815980384Z [HyperPodElasticAgent] 2025-06-29 21:45:27,815 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:646: [default] Rendezvous'ing worker group
# 2025-06-29T21:45:27.816665166Z [HyperPodElasticAgent] 2025-06-29 21:45:27,816 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:512: [default] Rendezvous complete for workers. Result:
# 2025-06-29T21:45:27.816668196Z   restart_count=0
# 2025-06-29T21:45:27.816670626Z   master_addr=10.1.176.117
# 2025-06-29T21:45:27.816672686Z   master_port=1234
# 2025-06-29T21:45:27.816674766Z   group_rank=0
# 2025-06-29T21:45:27.816676836Z   group_world_size=1
# 2025-06-29T21:45:27.816679056Z   local_ranks=[0]
# 2025-06-29T21:45:27.816688386Z   role_ranks=[0]
# 2025-06-29T21:45:27.816690616Z   global_ranks=[0]
# 2025-06-29T21:45:27.816692666Z   role_world_sizes=[1]
# 2025-06-29T21:45:27.816694896Z   global_world_sizes=[1]
# 2025-06-29T21:45:27.816696826Z
# 2025-06-29T21:45:27.816699386Z [HyperPodElasticAgent] 2025-06-29 21:45:27,816 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:654: [default] Starting worker group
# 2025-06-29T21:45:27.816754967Z [HyperPodElasticAgent] 2025-06-29 21:45:27,816 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:187: Starting workers with worker spec worker_group.spec=WorkerSpec(role='default', local_world_size=1, rdzv_handler=<amzn_hyper_pod_elastic_agent.rendezvous.hyperpod_rendezvous_backend.HyperPodRendezvousBackend object at 0x7f1f6da7bb90>, fn=None, entrypoint='/workspace/echo.sh', args=('Pre-training script',), max_restarts=3, monitor_interval=0.1, master_port=None, master_addr=None, local_addr=None)...
# 2025-06-29T21:45:27.816843429Z [HyperPodElasticAgent] 2025-06-29 21:45:27,816 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/local_elastic_agent.py:185: Environment variable 'TORCHELASTIC_ENABLE_FILE_TIMER' not found. Do not start FileTimerServer.
# 2025-06-29T21:45:27.816854779Z [HyperPodElasticAgent] 2025-06-29 21:45:27,816 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/local_elastic_agent.py:217: Environment variable 'TORCHELASTIC_HEALTH_CHECK_PORT' not found. Do not start health check.
# 2025-06-29T21:45:27.817140374Z [HyperPodElasticAgent] 2025-06-29 21:45:27,817 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:121: Setting up signal handler to reap zombie processes
# 2025-06-29T21:45:27.817953679Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:27.819133670Z INFO:Log Agent:Not starting Log Agent since Log Monitoring Configuration is empty
# 2025-06-29T21:45:27.820155608Z [HyperPodElasticAgent] 2025-06-29 21:45:27,820 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:133: Reaped child process 25 with status 0
# 2025-06-29T21:45:27.919012377Z [default0]:Running script...
# 2025-06-29T21:45:27.919021507Z [default0]:Arg 1: Pre-training script
# 2025-06-29T21:45:27.919024467Z [default0]:LOCAL_RANK: 0
# 2025-06-29T21:45:27.919026697Z [default0]:RANK: 0
# 2025-06-29T21:45:27.919028948Z [default0]:GROUP_RANK: 0
# 2025-06-29T21:45:27.919031158Z [default0]:ROLE_RANK: 0
# 2025-06-29T21:45:27.919033398Z [default0]:LOCAL_WORLD_SIZE: 1
# 2025-06-29T21:45:27.919035598Z [default0]:WORLD_SIZE: 1
# 2025-06-29T21:45:27.919037768Z [default0]:GROUP_WORLD_SIZE: 1
# 2025-06-29T21:45:27.919039948Z [default0]:MASTER_ADDR: 10.1.176.117
# 2025-06-29T21:45:27.919042188Z [default0]:MASTER_PORT: 1234
# 2025-06-29T21:45:27.919044438Z [default0]:TORCHELASTIC_RESTART_COUNT: 0
# 2025-06-29T21:45:27.919046688Z [default0]:TORCHELASTIC_MAX_RESTARTS: 3
# 2025-06-29T21:45:28.019538006Z [HyperPodElasticAgent] 2025-06-29 21:45:28,019 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:646: [default] Rendezvous'ing worker group
# 2025-06-29T21:45:28.019969854Z [HyperPodElasticAgent] 2025-06-29 21:45:28,019 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:512: [default] Rendezvous complete for workers. Result:
# 2025-06-29T21:45:28.019973314Z   restart_count=0
# 2025-06-29T21:45:28.019975774Z   master_addr=10.1.176.117
# 2025-06-29T21:45:28.019978354Z   master_port=1234
# 2025-06-29T21:45:28.019988164Z   group_rank=0
# 2025-06-29T21:45:28.019990604Z   group_world_size=1
# 2025-06-29T21:45:28.019992914Z   local_ranks=[0]
# 2025-06-29T21:45:28.019995114Z   role_ranks=[0]
# 2025-06-29T21:45:28.019997334Z   global_ranks=[0]
# 2025-06-29T21:45:28.019999504Z   role_world_sizes=[1]
# 2025-06-29T21:45:28.020001664Z   global_world_sizes=[1]
# 2025-06-29T21:45:28.020003734Z
# 2025-06-29T21:45:28.020006215Z [HyperPodElasticAgent] 2025-06-29 21:45:28,019 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:654: [default] Starting worker group
# 2025-06-29T21:45:28.020069736Z [HyperPodElasticAgent] 2025-06-29 21:45:28,019 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:187: Starting workers with worker spec worker_group.spec=WorkerSpec(role='default', local_world_size=1, rdzv_handler=<amzn_hyper_pod_elastic_agent.rendezvous.hyperpod_rendezvous_backend.HyperPodRendezvousBackend object at 0x7f1f6da7bb90>, fn=None, entrypoint='/opt/conda/bin/python', args=('-u', '/workspace/mnist.py', '--epochs=2', '--backend=gloo', '--no-cuda'), max_restarts=3, monitor_interval=0.1, master_port=None, master_addr=None, local_addr=None)...
# 2025-06-29T21:45:28.020180838Z [HyperPodElasticAgent] 2025-06-29 21:45:28,020 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/local_elastic_agent.py:185: Environment variable 'TORCHELASTIC_ENABLE_FILE_TIMER' not found. Do not start FileTimerServer.
# 2025-06-29T21:45:28.020186148Z [HyperPodElasticAgent] 2025-06-29 21:45:28,020 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/local_elastic_agent.py:217: Environment variable 'TORCHELASTIC_HEALTH_CHECK_PORT' not found. Do not start health check.
# 2025-06-29T21:45:28.020481013Z [HyperPodElasticAgent] 2025-06-29 21:45:28,020 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:121: Setting up signal handler to reap zombie processes
# 2025-06-29T21:45:28.021675114Z INFO:Log Agent:Not starting Log Agent since Log Monitoring Configuration is empty
# 2025-06-29T21:45:28.839194653Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:29.507643875Z [HyperPodElasticAgent] 2025-06-29 21:45:29,507 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:133: Reaped child process 16 with status 0
# 2025-06-29T21:45:29.850522931Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:30.123850192Z [default0]:2025-06-29 21:45:30,122 [INFO] __main__: World Size: 1. Rank: 0
# 2025-06-29T21:45:30.123863622Z [default0]:2025-06-29 21:45:30,122 [INFO] __main__: [Rank=0 LocalRank=0] Training script started
# 2025-06-29T21:45:30.223897163Z [default0]:Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 2025-06-29T21:45:30.223953634Z [default0]:2025-06-29 21:45:30,124 [INFO] __main__: Using distributed PyTorch with gloo backend
# 2025-06-29T21:45:30.524154495Z [default0]:Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 2025-06-29T21:45:30.824632572Z [default0]:
# 2025-06-29T21:45:30.862950198Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:30.924703783Z [default0]:  0%|          | 0/26421880 [00:00<?, ?it/s][default0]:
# 2025-06-29T21:45:31.124900535Z [default0]:  0%|          | 32768/26421880 [00:00<01:50, 238630.42it/s][default0]:
# 2025-06-29T21:45:31.225042477Z [default0]:  0%|          | 65536/26421880 [00:00<01:50, 237486.54it/s][default0]:
# 2025-06-29T21:45:31.425209749Z [default0]:  0%|          | 131072/26421880 [00:00<01:16, 345540.50it/s][default0]:
# 2025-06-29T21:45:31.525322570Z [default0]:  1%|          | 196608/26421880 [00:00<01:06, 396183.36it/s][default0]:
# 2025-06-29T21:45:31.625432632Z [default0]:  1%|          | 327680/26421880 [00:00<00:43, 595549.09it/s][default0]:
# 2025-06-29T21:45:31.825639106Z [default0]:  2%|▏         | 589824/26421880 [00:00<00:24, 1038518.81it/s][default0]:
# 2025-06-29T21:45:31.874633983Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:31.925735797Z [default0]:  4%|▍         | 1179648/26421880 [00:00<00:12, 2093486.96it/s][default0]:
# 2025-06-29T21:45:32.025887969Z [default0]:  9%|▉         | 2326528/26421880 [00:01<00:05, 4069800.22it/s][default0]:
# 2025-06-29T21:45:32.226074942Z [default0]: 18%|█▊        | 4653056/26421880 [00:01<00:02, 8057602.42it/s][default0]:
# 2025-06-29T21:45:32.326190253Z [default0]: 29%|██▉       | 7700480/26421880 [00:01<00:01, 12382266.10it/s][default0]:
# 2025-06-29T21:45:32.495421741Z [default0]: 41%|████      | 10846208/26421880 [00:01<00:01, 15559980.39it/s][HyperPodElasticAgent] 2025-06-29 21:45:32,495 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:133: Reaped child process 41 with status 0
# 2025-06-29T21:45:32.526408626Z [default0]:
# 2025-06-29T21:45:32.626517777Z [default0]: 52%|█████▏    | 13860864/26421880 [00:01<00:00, 17460626.78it/s][default0]:
# 2025-06-29T21:45:32.726711740Z [default0]: 64%|██████▍   | 16875520/26421880 [00:01<00:00, 18776630.30it/s][default0]:
# 2025-06-29T21:45:32.885249798Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:32.926852292Z [default0]: 76%|███████▌  | 19988480/26421880 [00:01<00:00, 19889636.81it/s][default0]:
# 2025-06-29T21:45:33.026940233Z [default0]: 87%|████████▋ | 23101440/26421880 [00:02<00:00, 20677308.00it/s][default0]:
# 2025-06-29T21:45:33.026951043Z [default0]: 99%|█████████▊| 26050560/26421880 [00:02<00:00, 20893267.56it/s]
# 2025-06-29T21:45:33.026953553Z [default0]:100%|██████████| 26421880/26421880 [00:02<00:00, 11931561.91it/s]
# 2025-06-29T21:45:33.126587696Z [default0]:Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
# 2025-06-29T21:45:33.426946421Z [default0]:
# 2025-06-29T21:45:33.426960831Z [default0]:Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 2025-06-29T21:45:33.727183384Z [default0]:Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 2025-06-29T21:45:33.896109597Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:34.027764163Z [default0]:
# 2025-06-29T21:45:34.127527338Z [default0]:Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# 2025-06-29T21:45:34.127535328Z [default0]:
# 2025-06-29T21:45:34.127537789Z [default0]:Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 2025-06-29T21:45:34.127854664Z [default0]:  0%|          | 0/29515 [00:00<?, ?it/s][default0]:
# 2025-06-29T21:45:34.127858084Z [default0]:100%|██████████| 29515/29515 [00:00<00:00, 208531.41it/s]
# 2025-06-29T21:45:34.127860484Z [default0]:100%|██████████| 29515/29515 [00:00<00:00, 208380.48it/s]
# 2025-06-29T21:45:34.427816962Z [default0]:Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 2025-06-29T21:45:37.431419170Z [default0]:2025-06-29 21:45:37,335 [INFO] __main__: Train Epoch: 1 [1280/60000 (2%)]	loss=2.2672
# 2025-06-29T21:45:37.531447860Z [default0]:2025-06-29 21:45:37,493 [INFO] __main__: Train Epoch: 1 [1920/60000 (3%)]	loss=2.2652
# 2025-06-29T21:45:37.731696203Z [default0]:2025-06-29 21:45:37,646 [INFO] __main__: Train Epoch: 1 [2560/60000 (4%)]	loss=2.2623
# 2025-06-29T21:45:37.831797844Z [default0]:2025-06-29 21:45:37,799 [INFO] __main__: Train Epoch: 1 [3200/60000 (5%)]	loss=2.2530
# 2025-06-29T21:45:37.946157901Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:38.032054918Z [default0]:2025-06-29 21:45:37,953 [INFO] __main__: Train Epoch: 1 [3840/60000 (6%)]	loss=2.2258
# 2025-06-29T21:45:38.132189730Z [default0]:2025-06-29 21:45:38,105 [INFO] __main__: Train Epoch: 1 [4480/60000 (7%)]	loss=2.2267
# 2025-06-29T21:45:38.332413713Z [default0]:2025-06-29 21:45:38,259 [INFO] __main__: Train Epoch: 1 [5120/60000 (9%)]	loss=2.1529
# 2025-06-29T21:45:38.432539265Z [default0]:2025-06-29 21:45:38,415 [INFO] __main__: Train Epoch: 1 [5760/60000 (10%)]	loss=2.1140
# 2025-06-29T21:45:38.632754228Z [default0]:2025-06-29 21:45:38,569 [INFO] __main__: Train Epoch: 1 [6400/60000 (11%)]	loss=2.0527
# 2025-06-29T21:45:38.732890029Z [default0]:2025-06-29 21:45:38,722 [INFO] __main__: Train Epoch: 1 [7040/60000 (12%)]	loss=1.9859
# 2025-06-29T21:45:38.933133403Z [default0]:2025-06-29 21:45:38,876 [INFO] __main__: Train Epoch: 1 [7680/60000 (13%)]	loss=1.8334
# 2025-06-29T21:45:38.958154920Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:45:39.033239594Z [default0]:2025-06-29 21:45:39,030 [INFO] __main__: Train Epoch: 1 [8320/60000 (14%)]	loss=1.7393
# 2025-06-29T21:45:39.233513718Z [default0]:2025-06-29 21:45:39,184 [INFO] __main__: Train Epoch: 1 [8960/60000 (15%)]	loss=1.3895
# 2025-06-29T21:45:39.433745071Z [default0]:2025-06-29 21:45:39,338 [INFO] __main__: Train Epoch: 1 [9600/60000 (16%)]	loss=1.3660
# 2025-06-29T21:45:39.533916913Z [default0]:2025-06-29 21:45:39,495 [INFO] __main__: Train Epoch: 1 [10240/60000 (17%)]	loss=1.1332
# 2025-06-29T21:45:39.734203197Z [default0]:2025-06-29 21:45:39,649 [INFO] __main__: Train Epoch: 1 [10880/60000 (18%)]	loss=1.0432
# 2025-06-29T21:45:39.834323339Z [default0]:2025-06-29 21:45:39,802 [INFO] __main__: Train Epoch: 1 [11520/60000 (19%)]	loss=1.2995
# 2025-06-29T21:45:39.969812354Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:46:09.173271129Z [default0]:accuracy=0.7911
# 2025-06-29T21:46:09.173275800Z [default0]:
# 2025-06-29T21:46:09.173280590Z [default0]:2025-06-29 21:46:09,153 [INFO] __main__: [Rank=0] Training script successful
# 2025-06-29T21:46:09.513687385Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK
# 2025-06-29T21:46:09.686111418Z [HyperPodElasticAgent] 2025-06-29 21:46:09,685 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:133: Reaped child process 29 with status 0
# 2025-06-29T21:46:09.874331723Z [HyperPodElasticAgent] 2025-06-29 21:46:09,874 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:646: [default] Rendezvous'ing worker group
# 2025-06-29T21:46:09.874816512Z [HyperPodElasticAgent] 2025-06-29 21:46:09,874 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:512: [default] Rendezvous complete for workers. Result:
# 2025-06-29T21:46:09.874825592Z   restart_count=0
# 2025-06-29T21:46:09.874828272Z   master_addr=10.1.176.117
# 2025-06-29T21:46:09.874830472Z   master_port=1234
# 2025-06-29T21:46:09.874832692Z   group_rank=0
# 2025-06-29T21:46:09.874834802Z   group_world_size=1
# 2025-06-29T21:46:09.874836862Z   local_ranks=[0]
# 2025-06-29T21:46:09.874838922Z   role_ranks=[0]
# 2025-06-29T21:46:09.874840982Z   global_ranks=[0]
# 2025-06-29T21:46:09.874843022Z   role_world_sizes=[1]
# 2025-06-29T21:46:09.874845183Z   global_world_sizes=[1]
# 2025-06-29T21:46:09.874847233Z
# 2025-06-29T21:46:09.874861323Z [HyperPodElasticAgent] 2025-06-29 21:46:09,874 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/api.py:654: [default] Starting worker group
# 2025-06-29T21:46:09.874918714Z [HyperPodElasticAgent] 2025-06-29 21:46:09,874 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:187: Starting workers with worker spec worker_group.spec=WorkerSpec(role='default', local_world_size=1, rdzv_handler=<amzn_hyper_pod_elastic_agent.rendezvous.hyperpod_rendezvous_backend.HyperPodRendezvousBackend object at 0x7f1f6da7bb90>, fn=None, entrypoint='/workspace/echo.sh', args=('Post-training script',), max_restarts=3, monitor_interval=0.1, master_port=None, master_addr=None, local_addr=None)...
# 2025-06-29T21:46:09.875004235Z [HyperPodElasticAgent] 2025-06-29 21:46:09,874 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/local_elastic_agent.py:185: Environment variable 'TORCHELASTIC_ENABLE_FILE_TIMER' not found. Do not start FileTimerServer.
# 2025-06-29T21:46:09.875034226Z [HyperPodElasticAgent] 2025-06-29 21:46:09,874 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/torch/distributed/elastic/agent/server/local_elastic_agent.py:217: Environment variable 'TORCHELASTIC_HEALTH_CHECK_PORT' not found. Do not start health check.
# 2025-06-29T21:46:09.875332111Z [HyperPodElasticAgent] 2025-06-29 21:46:09,875 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:121: Setting up signal handler to reap zombie processes
# 2025-06-29T21:46:09.876478682Z INFO:Log Agent:Not starting Log Agent since Log Monitoring Configuration is empty
# 2025-06-29T21:46:09.877623543Z [HyperPodElasticAgent] 2025-06-29 21:46:09,877 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/pcontext/pcontext.py:133: Reaped child process 58 with status 0
# 2025-06-29T21:46:09.977135223Z [default0]:Running script...
# 2025-06-29T21:46:09.977168293Z [default0]:Arg 1: Post-training script
# 2025-06-29T21:46:09.977189494Z [default0]:LOCAL_RANK: 0
# 2025-06-29T21:46:09.977192184Z [default0]:RANK: 0
# 2025-06-29T21:46:09.977194464Z [default0]:GROUP_RANK: 0
# 2025-06-29T21:46:09.977196684Z [default0]:ROLE_RANK: 0
# 2025-06-29T21:46:09.977199564Z [default0]:LOCAL_WORLD_SIZE: 1
# 2025-06-29T21:46:09.977205194Z [default0]:WORLD_SIZE: 1
# 2025-06-29T21:46:09.977207604Z [default0]:GROUP_WORLD_SIZE: 1
# 2025-06-29T21:46:09.977209874Z [default0]:MASTER_ADDR: 10.1.176.117
# 2025-06-29T21:46:09.977212074Z [default0]:MASTER_PORT: 1234
# 2025-06-29T21:46:09.977220864Z [default0]:TORCHELASTIC_RESTART_COUNT: 0
# 2025-06-29T21:46:09.977223224Z [default0]:TORCHELASTIC_MAX_RESTARTS: 3
# 2025-06-29T21:46:10.077393466Z [HyperPodElasticAgent] 2025-06-29 21:46:10,077 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/plr_hyperpod_elastic_agent.py:129: [default] worker group successfully finished.
# 2025-06-29T21:46:10.077418716Z [HyperPodElasticAgent] 2025-06-29 21:46:10,077 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:344: Transitioned from AgentState.RUNNING to AgentState.COMPLETED
# 2025-06-29T21:46:10.077465817Z [HyperPodElasticAgent] 2025-06-29 21:46:10,077 [INFO] [rank0-restart0] /opt/conda/lib/python3.11/site-packages/amzn_hyper_pod_elastic_agent/hyperpod_elastic_agent/hyperpod_elastic_agent.py:346: The agent is finished after the training script has exited successfully
# 2025-06-29T21:46:10.523537763Z INFO:     10.1.230.236:41788 - "GET /status HTTP/1.1" 200 OK

# %% [markdown]
# ### Delete the job

# %%
pytorch_job.delete()
# Out:
# Successful deleted HyperpodPytorchJob!
